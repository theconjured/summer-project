# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sn_compare = pd.read_csv('./stuff/scale_neighbors_compare.csv')

# %%
sn_compare
# Out:
#     Scale  Neighbors     Runtime  Guessed  False Positive  Missed  \
# 0     1.1          3   98.332240     6033            1577   10753
# 1     1.2          3   62.055313     3769             580   12020
# 2     1.6          3   36.702319     1301              71   13979
# 3     2.0          3   33.294737     1458              60   13811
# 4     2.5          3   31.963288      988              31   14252
# 5     3.0          3   31.364905      665               9   14553
# 6     5.0          3   29.613915      315               0   14894
# 7     8.0          3   37.511061      216              11   15004
# 8     1.1          1   92.831324    15060            7703    7852
# 9     1.1          2   90.956757     8679            3117    9647
# 10    1.1          3   89.639765     6033            1577   10753
# 11    1.1          4   89.441855     4710             958   11457
# 12    1.1          5   90.249457     3883             624   11950
# 13    1.1          6   97.528567     3331             422   12300
# 14    1.1          7   97.017795     2892             285   12602
# 15    1.1          8  100.662456     2616             218   12811
#
#     Likely Accurate
# 0              2679
# 1              2091
# 2               629
# 3               861
# 4               561
# 5               353
# 6               220
# 7               159
# 8              3394
# 9              2981
# 10             2679
# 11             2440
# 12             2262
# 13             2111
# 14             1961
# 15             1869

# %%
scale_varied = sn_compare.head(8)
scale_varied
# Out:
#    Scale  Neighbors    Runtime  Guessed  False Positive  Missed  \
# 0    1.1          3  98.332240     6033            1577   10753
# 1    1.2          3  62.055313     3769             580   12020
# 2    1.6          3  36.702319     1301              71   13979
# 3    2.0          3  33.294737     1458              60   13811
# 4    2.5          3  31.963288      988              31   14252
# 5    3.0          3  31.364905      665               9   14553
# 6    5.0          3  29.613915      315               0   14894
# 7    8.0          3  37.511061      216              11   15004
#
#    Likely Accurate
# 0             2679
# 1             2091
# 2              629
# 3              861
# 4              561
# 5              353
# 6              220
# 7              159

# %%
neighbors_varied = sn_compare.tail(8)
neighbors_varied
# Out:
#     Scale  Neighbors     Runtime  Guessed  False Positive  Missed  \
# 8     1.1          1   92.831324    15060            7703    7852
# 9     1.1          2   90.956757     8679            3117    9647
# 10    1.1          3   89.639765     6033            1577   10753
# 11    1.1          4   89.441855     4710             958   11457
# 12    1.1          5   90.249457     3883             624   11950
# 13    1.1          6   97.528567     3331             422   12300
# 14    1.1          7   97.017795     2892             285   12602
# 15    1.1          8  100.662456     2616             218   12811
#
#     Likely Accurate
# 8              3394
# 9              2981
# 10             2679
# 11             2440
# 12             2262
# 13             2111
# 14             1961
# 15             1869

# %%
ax = scale_varied.plot(x = 'Scale', y = 'Runtime', style = 'o-', title = 'Scale vs. Runtime')
ax.set_xlabel('Scale')
ax.set_ylabel('Runtime (s)')
plt.show()

# %%
ax = scale_varied.plot(x = 'Scale', y = ['Guessed', 'False Positive', 'Missed','Likely Accurate'], style = 'o-', title = 'Scale vs. Boxes Found')
ax.set_xlabel('Scale')
ax.set_ylabel('Number of Boxes')
plt.show()

# %%
ax = neighbors_varied.plot(x = 'Neighbors', y = 'Runtime', style = 'o-', title = 'Neighbors vs. Runtime')
ax.set_xlabel('Scale')
ax.set_ylabel('Runtime (s)')
plt.show()
